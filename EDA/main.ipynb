# %%
# Imports

import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import eurostat

# %%
df_gdp: pd.DataFrame = eurostat.get_data_df('nama_10_pc') # pyright: ignore[reportAssignmentType]
df_gdp.head()
# Out:
#   freq           unit na_item geo\TIME_PERIOD  1975  1976  1977  1978  1979  \
# 0    A  CLV10_EUR_HAB    B1GQ              AL   NaN   NaN   NaN   NaN   NaN
# 1    A  CLV10_EUR_HAB    B1GQ              AT   NaN   NaN   NaN   NaN   NaN
# 2    A  CLV10_EUR_HAB    B1GQ              BE   NaN   NaN   NaN   NaN   NaN
# 3    A  CLV10_EUR_HAB    B1GQ              BG   NaN   NaN   NaN   NaN   NaN
# 4    A  CLV10_EUR_HAB    B1GQ              CH   NaN   NaN   NaN   NaN   NaN
#
#    1980  ...     2015     2016     2017     2018     2019     2020     2021  \
# 0   NaN  ...   3480.0   3620.0   3750.0   3890.0   3990.0   3880.0   4270.0
# 1   NaN  ...  35930.0  36230.0  36820.0  37550.0  38040.0  35480.0  37080.0
# 2   NaN  ...  34090.0  34320.0  34700.0  35190.0  35850.0  33990.0  35960.0
# 3   NaN  ...   5850.0   6110.0   6360.0   6600.0   6950.0   6800.0   7380.0
# 4   NaN  ...  59540.0  60130.0  60380.0  61660.0  61920.0  60140.0  63020.0
#
#       2022     2023     2024
# ...

# %%
df_gdp = df_gdp.rename(columns={"geo\\TIME_PERIOD":"geo"})
df_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4401 entries, 0 to 4400
# Data columns (total 54 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   freq     4401 non-null   object
#  1   unit     4401 non-null   object
#  2   na_item  4401 non-null   object
#  3   geo      4401 non-null   object
#  4   1975     243 non-null    float64
#  5   1976     243 non-null    float64
#  6   1977     243 non-null    float64
#  7   1978     243 non-null    float64
#  8   1979     243 non-null    float64
#  9   1980     315 non-null    float64
#  10  1981     324 non-null    float64
#  11  1982     324 non-null    float64
#  12  1983     324 non-null    float64
#  13  1984     324 non-null    float64
#  14  1985     324 non-null    float64
#  15  1986     324 non-null    float64
#  16  1987     324 non-null    float64
#  17  1988     324 non-null    float64
#  18  1989     324 non-null    float64
#  19  1990     324 non-null    float64
# ...

# %%
df_gdp_sweden: pd.DataFrame = df_gdp[df_gdp["geo"] == "SE"]
df_gdp_sweden.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, 36 to 4396
# Data columns (total 54 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   freq     108 non-null    object
#  1   unit     108 non-null    object
#  2   na_item  108 non-null    object
#  3   geo      108 non-null    object
#  4   1975     0 non-null      float64
#  5   1976     0 non-null      float64
#  6   1977     0 non-null      float64
#  7   1978     0 non-null      float64
#  8   1979     0 non-null      float64
#  9   1980     0 non-null      float64
#  10  1981     0 non-null      float64
#  11  1982     0 non-null      float64
#  12  1983     0 non-null      float64
#  13  1984     0 non-null      float64
#  14  1985     0 non-null      float64
#  15  1986     0 non-null      float64
#  16  1987     0 non-null      float64
#  17  1988     0 non-null      float64
#  18  1989     0 non-null      float64
#  19  1990     0 non-null      float64
# ...

# %%
non_null_columns = df_gdp_sweden.columns[~(df_gdp_sweden.isnull().sum() > 20)]
df_gdp_sweden = df_gdp_sweden[non_null_columns]

non_null_columns
# Out:
# Index(['freq', 'unit', 'na_item', 'geo', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
#       dtype='object')

# %%
df_gdp_sweden.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, 36 to 4396
# Data columns (total 34 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   freq     108 non-null    object
#  1   unit     108 non-null    object
#  2   na_item  108 non-null    object
#  3   geo      108 non-null    object
#  4   1995     108 non-null    float64
#  5   1996     108 non-null    float64
#  6   1997     108 non-null    float64
#  7   1998     108 non-null    float64
#  8   1999     108 non-null    float64
#  9   2000     108 non-null    float64
#  10  2001     108 non-null    float64
#  11  2002     108 non-null    float64
#  12  2003     108 non-null    float64
#  13  2004     108 non-null    float64
#  14  2005     108 non-null    float64
#  15  2006     108 non-null    float64
#  16  2007     108 non-null    float64
#  17  2008     108 non-null    float64
#  18  2009     108 non-null    float64
#  19  2010     108 non-null    float64
# ...

# %%
df_gdp_sweden.head(25)
# Out:
#      freq           unit      na_item geo     1995     1996     1997     1998  \
# 36      A  CLV10_EUR_HAB         B1GQ  SE  28870.0  29320.0  30210.0  31470.0
# 77      A  CLV10_EUR_HAB           P3  SE  22400.0  22680.0  23120.0  23890.0
# 117     A  CLV10_EUR_HAB      P31_S13  SE   6670.0   6750.0   6650.0   6920.0
# 158     A  CLV10_EUR_HAB      P31_S14  SE  12930.0  13200.0  13630.0  14090.0
# 199     A  CLV10_EUR_HAB  P31_S14_S15  SE  13300.0  13580.0  14020.0  14480.0
# 240     A  CLV10_EUR_HAB      P31_S15  SE    370.0    370.0    380.0    380.0
# 280     A  CLV10_EUR_HAB      P32_S13  SE   2650.0   2540.0   2600.0   2660.0
# 321     A  CLV10_EUR_HAB       P3_S13  SE   9330.0   9290.0   9250.0   9580.0
# 361     A  CLV10_EUR_HAB          P41  SE  19800.0  20170.0  20560.0  21280.0
# 402     A  CLV15_EUR_HAB         B1GQ  SE  31610.0  32100.0  33070.0  34460.0
# 443     A  CLV15_EUR_HAB           P3  SE  24620.0  24930.0  25420.0  26270.0
# ...
